# %%
# pip install bing-image-downloader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bing_image_downloader import downloader

downloader.download("Sensor LM 35", limit = 130, output_dir = 'D:/Dataset Sensor EWS Trafo/LM 35', adult_filter_off = True)
# Out:
# [%] Downloading Images to D:\Dataset Sensor EWS Trafo\LM 35\Sensor LM 35
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 16 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn1-shop.mikroe.com/img/product/lm35-sensor/lm35-sensor-thickbox_default-1.jpg
# [Error]Invalid image, not saving https://cdn1-shop.mikroe.com/img/product/lm35-sensor/lm35-sensor-thickbox_default-1.jpg
#
# [!] Issue getting: https://cdn1-shop.mikroe.com/img/product/lm35-sensor/lm35-sensor-thickbox_default-1.jpg
# [!] Error:: Invalid image, not saving https://cdn1-shop.mikroe.com/img/product/lm35-sensor/lm35-sensor-thickbox_default-1.jpg
#
# [%] Downloading Image #1 from http://i2.wp.com/maxembedded.files.wordpress.com/2011/06/lm35.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://exploreembedded.com/wiki/images/f/f3/1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://5.imimg.com/data5/JM/CF/MY-33205970/lm35-sensor-500x500.png
# [%] File Downloaded !
#
# ...

# %%
# !zip -r /content/LM35.zip /content/LM35
